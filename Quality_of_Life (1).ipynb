# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split

from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor

from sklearn.metrics import (
    mean_absolute_error,
    mean_squared_error,
    r2_score
)

from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Data Collection

# %%
df = pd.read_csv("Quality_of_Life.csv")

df.head()
# Out:
#          country  Purchasing Power Value Purchasing Power Category  \
# 0    Afghanistan                   32.15                'Very Low'
# 1  Aland Islands                  125.01               'Very High'
# 2        Albania                   42.82                     'Low'
# 3       Alderney                    0.00                       NaN
# 4        Algeria                   27.60                'Very Low'
#
#    Safety Value Safety Category  Health Care Value Health Care Category  \
# 0         25.33           'Low'              24.24                'Low'
# 1         71.81          'High'              79.72               'High'
# 2         55.52      'Moderate'              48.21           'Moderate'
# 3         83.79     'Very High'             100.00          'Very High'
# 4         47.54      'Moderate'              54.43           'Moderate'
#
#    Climate Value Climate Category  Cost of Living Value  \
# 0           0.00              NaN                 21.08
# ...

# %%
## View Dataset

# %%
df.shape
# Out:
# (236, 19)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 236 entries, 0 to 235
# Data columns (total 19 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   country                            236 non-null    object
#  1   Purchasing Power Value             236 non-null    float64
#  2   Purchasing Power Category          190 non-null    object
#  3   Safety Value                       236 non-null    float64
#  4   Safety Category                    234 non-null    object
#  5   Health Care Value                  236 non-null    float64
#  6   Health Care Category               221 non-null    object
#  7   Climate Value                      236 non-null    float64
#  8   Climate Category                   114 non-null    object
#  9   Cost of Living Value               236 non-null    float64
#  10  Cost of Living Category            191 non-null    object
# ...

# %%
df.describe()
# Out:
#        Purchasing Power Value  Safety Value  Health Care Value  Climate Value  \
# count              236.000000    236.000000         236.000000     236.000000
# mean                55.573305     55.274449          54.731568      37.598178
# std                 52.008245     16.914298          20.607381      40.851542
# min                  0.000000      0.000000           0.000000      -3.540000
# 25%                 16.340000     43.857500          45.807500       0.000000
# 50%                 42.930000     54.635000          57.150000       0.000000
# 75%                 85.940000     68.132500          68.447500      79.332500
# max                281.830000    100.000000         100.000000      99.890000
#
#        Cost of Living Value  Traffic Commute Time Value  Pollution Value
# count            236.000000                  236.000000       236.000000
# mean              37.526314                   28.492966        54.266186
# ...

# %% [markdown]
# ###  Data Cleaning & Preprocessing

# %%
## Check Missing Values

# %%
df.isnull().sum()
# Out:
# country                                0
# Purchasing Power Value                 0
# Purchasing Power Category             46
# Safety Value                           0
# Safety Category                        2
# Health Care Value                      0
# Health Care Category                  15
# Climate Value                          0
# Climate Category                     122
# Cost of Living Value                   0
# Cost of Living Category               45
# Property Price to Income Value         0
# Property Price to Income Category     21
# Traffic Commute Time Value             0
# Traffic Commute Time Category         29
# Pollution Value                        0
# Pollution Category                    10
# Quality of Life Value                  0
# Quality of Life Category             122
# dtype: int64

# %%
 ## replace the missing values with "Unknown".

# %%
category_cols = [col for col in df.columns if "Category" in col]

df[category_cols] = df[category_cols].fillna("Unknown")

# %%
## verify:

# %%
df[category_cols].isnull().sum()
# Out:
# Purchasing Power Category            0
# Safety Category                      0
# Health Care Category                 0
# Climate Category                     0
# Cost of Living Category              0
# Property Price to Income Category    0
# Traffic Commute Time Category        0
# Pollution Category                   0
# Quality of Life Category             0
# dtype: int64

# %%
## Check for duplicate rows

# %%
print("Duplicate rows:", df.duplicated().sum())
# Out:
# Duplicate rows: 0

# %%
df = df.drop_duplicates()

# %%
## Verify data types

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 236 entries, 0 to 235
# Data columns (total 19 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   country                            236 non-null    object
#  1   Purchasing Power Value             236 non-null    float64
#  2   Purchasing Power Category          236 non-null    object
#  3   Safety Value                       236 non-null    float64
#  4   Safety Category                    236 non-null    object
#  5   Health Care Value                  236 non-null    float64
#  6   Health Care Category               236 non-null    object
#  7   Climate Value                      236 non-null    float64
#  8   Climate Category                   236 non-null    object
#  9   Cost of Living Value               236 non-null    float64
#  10  Cost of Living Category            236 non-null    object
# ...

# %%
## check column if it hasn't already been converted.

# %%
df["Property Price to Income Value"] = pd.to_numeric(
    df["Property Price to Income Value"],
    errors="coerce"
)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 236 entries, 0 to 235
# Data columns (total 19 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   country                            236 non-null    object
#  1   Purchasing Power Value             236 non-null    float64
#  2   Purchasing Power Category          236 non-null    object
#  3   Safety Value                       236 non-null    float64
#  4   Safety Category                    236 non-null    object
#  5   Health Care Value                  236 non-null    float64
#  6   Health Care Category               236 non-null    object
#  7   Climate Value                      236 non-null    float64
#  8   Climate Category                   236 non-null    object
#  9   Cost of Living Value               236 non-null    float64
#  10  Cost of Living Category            236 non-null    object
# ...

# %%
df["Property Price to Income Value"].unique()[:20]
# Out:
# array([ 7.8 ,  5.33, 14.88,  0.  , 21.7 ,  9.03,  8.01,  1.84, 20.05,
#        20.95,  5.32,  8.25, 11.76, 15.24,  4.9 , 12.26, 14.67, 12.79,
#         6.82,  6.06])

# %%
## Remove Quotes from Category Columns

# %%
category_cols = [col for col in df.columns if "Category" in col]

for col in category_cols:
    df[col] = df[col].astype(str).str.replace("'", "", regex=False)

# %%
## Drop the category columns before building your machine learning model:

# %%
category_cols = [col for col in df.columns if "Category" in col]

df_ml = df.drop(columns=category_cols)

# %%
df.head()
# Out:
#          country  Purchasing Power Value Purchasing Power Category  \
# 0    Afghanistan                   32.15                  Very Low
# 1  Aland Islands                  125.01                 Very High
# 2        Albania                   42.82                       Low
# 3       Alderney                    0.00                   Unknown
# 4        Algeria                   27.60                  Very Low
#
#    Safety Value Safety Category  Health Care Value Health Care Category  \
# 0         25.33             Low              24.24                  Low
# 1         71.81            High              79.72                 High
# 2         55.52        Moderate              48.21             Moderate
# 3         83.79       Very High             100.00            Very High
# 4         47.54        Moderate              54.43             Moderate
#
#    Climate Value Climate Category  Cost of Living Value  \
# 0           0.00          Unknown                 21.08
# ...

# %%
## Clean Quality of Life Values

## Your Quality of Life column contains values like

# %%
df["Quality of Life Value"] = (
    df["Quality of Life Value"]
    .astype(str)
    .str.replace(":", "")
    .str.replace("'", "")
    .str.strip()
)

df["Quality of Life Value"] = pd.to_numeric(
    df["Quality of Life Value"],
    errors="coerce"
)

# %%
## Replace Zero Values with NaN

# %%
numeric_cols = df.select_dtypes(include=np.number).columns

df[numeric_cols] = df[numeric_cols].replace(0, np.nan)

# %%
## Fill Missing Values

# %%
df[numeric_cols] = df[numeric_cols].fillna(
    df[numeric_cols].median()
)

# %% [markdown]
# ### Exploratory Data Analysis (EDA)

# %%
## Business Question: What does the dataset look like? Display the First Five Rows

# %%
df.head()
# Out:
#          country  Purchasing Power Value Purchasing Power Category  \
# 0    Afghanistan                   32.15                  Very Low
# 1  Aland Islands                  125.01                 Very High
# 2        Albania                   42.82                       Low
# 3       Alderney                   52.70                   Unknown
# 4        Algeria                   27.60                  Very Low
#
#    Safety Value Safety Category  Health Care Value Health Care Category  \
# 0         25.33             Low              24.24                  Low
# 1         71.81            High              79.72                 High
# 2         55.52        Moderate              48.21             Moderate
# 3         83.79       Very High             100.00            Very High
# 4         47.54        Moderate              54.43             Moderate
#
#    Climate Value Climate Category  Cost of Living Value  \
# 0          80.60          Unknown                 21.08
# ...

# %% [raw]
#  Display the Last Five Rows

# %%
df.tail()
# Out:
#                country  Purchasing Power Value Purchasing Power Category  \
# 231  Wallis And Futuna                   52.70                   Unknown
# 232     Western Sahara                   52.70                   Unknown
# 233              Yemen                   20.74                  Very Low
# 234             Zambia                   22.32                  Very Low
# 235           Zimbabwe                   28.76                  Very Low
#
#      Safety Value Safety Category  Health Care Value Health Care Category  \
# 231        54.745         Unknown              58.15              Unknown
# 232        62.870            High              58.15              Unknown
# 233        34.070             Low              25.31                  Low
# 234        54.390        Moderate              54.44             Moderate
# 235        39.310             Low              44.80             Moderate
#
#      Climate Value Climate Category  Cost of Living Value  \
# ...

# %% [markdown]
# Dataset Shape
#
# Business Question: How many countries and variables are included?

# %%
print(f"Rows: {df.shape[0]}")
print(f"Columns: {df.shape[1]}")
# Out:
# Rows: 236
# Columns: 19

# %% [raw]
# Dataset Information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 236 entries, 0 to 235
# Data columns (total 19 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   country                            236 non-null    object
#  1   Purchasing Power Value             236 non-null    float64
#  2   Purchasing Power Category          236 non-null    object
#  3   Safety Value                       236 non-null    float64
#  4   Safety Category                    236 non-null    object
#  5   Health Care Value                  236 non-null    float64
#  6   Health Care Category               236 non-null    object
#  7   Climate Value                      236 non-null    float64
#  8   Climate Category                   236 non-null    object
#  9   Cost of Living Value               236 non-null    float64
#  10  Cost of Living Category            236 non-null    object
# ...

# %% [raw]
# Summary Statistics
#
# Business Question: What are the average, minimum, and maximum values for each indicator?

# %%
df.describe().T
# Out:
#                                 count        mean        std    min       25%  \
# Purchasing Power Value          236.0   65.845339  44.676320   2.55   36.7000
# Safety Value                    236.0   55.738390  16.120715  15.89   44.2375
# Health Care Value               236.0   58.427542  14.848796  18.52   49.1325
# Climate Value                   236.0   79.264280  12.308687  -3.54   80.6000
# Cost of Living Value            236.0   45.481398  18.642349  17.90   34.6450
# Property Price to Income Value  236.0   23.328390  51.556796   0.55    8.1350
# Traffic Commute Time Value      236.0   33.227034  12.795320   2.95   27.0300
# Pollution Value                 236.0   57.099153  22.901903   1.72   40.0900
# Quality of Life Value           236.0  132.545169  28.700765  17.47  130.4200
#
#                                     50%       75%     max
# Purchasing Power Value           52.700   85.9400  281.83
# Safety Value                     54.745   68.1325  100.00
# ...

# %% [raw]
# Univariate Analysis
# 6. Distribution of Quality of Life
#
# Business Question: How are Quality of Life scores distributed across countries?

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))

plt.hist(df["Quality of Life Value"], bins=20)

plt.title("Distribution of Quality of Life")

plt.xlabel("Quality of Life Score")

plt.ylabel("Number of Countries")

plt.show()

# %% [raw]
# Interpretation
#
# Is the distribution normal?
# Are most countries clustered in the middle?
# Are there any extreme values?

# %% [raw]
# Distribution of Purchasing Power

# %%
plt.figure(figsize=(8,5))

plt.hist(df["Purchasing Power Value"], bins=20)

plt.title("Distribution of Purchasing Power")

plt.xlabel("Purchasing Power")

plt.ylabel("Frequency")

plt.show()

# %% [raw]
# Distribution of Healthcare

# %%
plt.figure(figsize=(8,5))

plt.hist(df["Health Care Value"], bins=20)

plt.title("Distribution of Healthcare")

plt.xlabel("Healthcare")

plt.ylabel("Frequency")

plt.show()

# %% [raw]
# Distribution of Safety

# %%
plt.figure(figsize=(8,5))

plt.hist(df["Safety Value"], bins=20)

plt.title("Distribution of Safety")

plt.xlabel("Safety")

plt.ylabel("Frequency")

plt.show()

# %% [raw]
# op Countries
# 10. Top 10 Countries by Quality of Life
#
# Business Question: Which countries provide the best quality of life?

# %%
top10 = df.nlargest(10, "Quality of Life Value")

plt.figure(figsize=(10,6))

plt.barh(
    top10["country"],
    top10["Quality of Life Value"]
)

plt.title("Top 10 Countries by Quality of Life")

plt.xlabel("Quality of Life Score")

plt.gca().invert_yaxis()

plt.show()

print(top10[["country","Quality of Life Value"]])
# Out:
#          country  Quality of Life Value
# 123   Luxembourg                 224.31
# 159         Oman                 213.42
# 148  Netherlands                 211.85
# 55       Denmark                 208.65
# 204  Switzerland                 204.91
# 70       Finland                 203.06
# 95       Iceland                 202.04
# 158       Norway                 194.48
# 203       Sweden                 193.48
# 171        Qatar                 192.73

# %% [raw]
# Bottom 10 Countries

# %%
bottom10 = df.nsmallest(10,"Quality of Life Value")

plt.figure(figsize=(10,6))

plt.barh(
    bottom10["country"],
    bottom10["Quality of Life Value"]
)

plt.title("Bottom 10 Countries by Quality of Life")

plt.xlabel("Quality of Life Score")

plt.gca().invert_yaxis()

plt.show()

print(bottom10[["country","Quality of Life Value"]])
# Out:
#                  country  Quality of Life Value
# 79                 Ghana                  17.47
# 29              Botswana                  36.55
# 153              Nigeria                  41.24
# 66              Ethiopia                  48.88
# 139             Mongolia                  62.52
# 18            Bangladesh                  74.51
# 200            Sri Lanka                  75.17
# 36              Cambodia                  78.92
# 105              Jamaica                  83.92
# 213  Trinidad And Tobago                  84.52

# %% [raw]
# Bivariate Analysis
# 12. Purchasing Power vs Quality of Life
#
# Business Question: Does higher purchasing power lead to higher Quality of Life?

# %%
plt.figure(figsize=(8,6))

plt.scatter(
    df["Purchasing Power Value"],
    df["Quality of Life Value"]
)

plt.xlabel("Purchasing Power")

plt.ylabel("Quality of Life")

plt.title("Purchasing Power vs Quality of Life")

plt.show()

# %% [raw]
# Healthcare vs Quality of Life

# %%
plt.figure(figsize=(8,6))

plt.scatter(
    df["Health Care Value"],
    df["Quality of Life Value"]
)

plt.xlabel("Healthcare")

plt.ylabel("Quality of Life")

plt.title("Healthcare vs Quality of Life")

plt.show()

# %% [raw]
# Safety vs Quality of Life

# %%
plt.figure(figsize=(8,6))

plt.scatter(
    df["Safety Value"],
    df["Quality of Life Value"]
)

plt.xlabel("Safety")

plt.ylabel("Quality of Life")

plt.title("Safety vs Quality of Life")

plt.show()

# %% [raw]
# Pollution vs Quality of Life
#
# Business Question: Does pollution reduce Quality of Life?

# %%
plt.figure(figsize=(8,6))

plt.scatter(
    df["Pollution Value"],
    df["Quality of Life Value"]
)

plt.xlabel("Pollution")

plt.ylabel("Quality of Life")

plt.title("Pollution vs Quality of Life")

plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import os

# Create images folder if it doesn't exist
os.makedirs("images", exist_ok=True)

# Correlation matrix
corr = df.select_dtypes(include="number").corr()

# Create figure
plt.figure(figsize=(10,8))

# Draw heatmap
sns.heatmap(
    corr,
    annot=True,
    cmap="coolwarm",
    fmt=".2f",
    linewidths=0.5,
    annot_kws={"size":9}
)

plt.title("Correlation Matrix")

plt.tight_layout()

# Save the image BEFORE showing it
plt.savefig(
    "images/correlation_heatmap.png",
    dpi=300,
    bbox_inches="tight"
)

# Display the plot
plt.show()

# %% [raw]
# Correlation Analysis
# 16. Correlation Matrix
#
# Business Question: Which indicators have the strongest relationship with Quality of Life?

# %% [raw]
# Correlation with Quality of Life

# %%
quality_corr = (
    corr["Quality of Life Value"]
    .sort_values(ascending=False)
)

print(quality_corr)
# Out:
# Quality of Life Value             1.000000
# Purchasing Power Value            0.569030
# Cost of Living Value              0.362809
# Safety Value                      0.340216
# Health Care Value                 0.292982
# Climate Value                     0.028355
# Property Price to Income Value   -0.120441
# Traffic Commute Time Value       -0.277431
# Pollution Value                  -0.487968
# Name: Quality of Life Value, dtype: float64

# %% [raw]
# Outlier Detection
# 18. Boxplots
#
# Business Question: Are there countries with unusually high or low values?

# %%
numeric_columns = [
    "Purchasing Power Value",
    "Safety Value",
    "Health Care Value",
    "Climate Value",
    "Cost of Living Value",
    "Property Price to Income Value",
    "Traffic Commute Time Value",
    "Pollution Value",
    "Quality of Life Value"
]

plt.figure(figsize=(14,8))

df[numeric_columns].boxplot(rot=45)

plt.title("Boxplots of Numeric Features")

plt.show()

# %% [raw]
# Category Analysis
# 19. Number of Countries in Each Quality of Life Category

# %%
df["Quality of Life Category"].value_counts()
# Out:
# Quality of Life Category
# Unknown      122
# Very High     33
# Very Low      26
# Moderate      25
# Low           19
# High          11
# Name: count, dtype: int64

# %%
df["Quality of Life Category"].value_counts().plot(
    kind="bar"
)

plt.title("Countries by Quality of Life Category")

plt.xlabel("Category")

plt.ylabel("Number of Countries")

plt.show()

# %% [raw]
# Machine Learning

# %% [raw]
# Select Features and Target
#
# Business Question: Can we predict a country's Quality of Life score using socioeconomic indicators?

# %%
# Features (Independent Variables)
X = df[
    [
        "Purchasing Power Value",
        "Safety Value",
        "Health Care Value",
        "Climate Value",
        "Cost of Living Value",
        "Property Price to Income Value",
        "Traffic Commute Time Value",
        "Pollution Value"
    ]
]

# Target (Dependent Variable)
y = df["Quality of Life Value"]

print(X.head())
print(y.head())
# Out:
#    Purchasing Power Value  Safety Value  Health Care Value  Climate Value  \
# 0                   32.15         25.33              24.24          80.60
# 1                  125.01         71.81              79.72          80.60
# 2                   42.82         55.52              48.21          86.43
# 3                   52.70         83.79             100.00          80.60
# 4                   27.60         47.54              54.43          94.82
#
#    Cost of Living Value  Property Price to Income Value  \
# 0                 21.08                            7.80
# 1                 53.44                            5.33
# 2                 40.85                           14.88
# 3                 41.72                           12.41
# 4                 25.31                           21.70
#
#    Traffic Commute Time Value  Pollution Value
# 0                       56.17            84.44
# 1                       19.05            18.05
# ...

# %% [raw]
# Split the Dataset

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42
)

print("Training samples:", X_train.shape)
print("Testing samples:", X_test.shape)
# Out:
# Training samples: (188, 8)
# Testing samples: (48, 8)

# %% [raw]
# Train a Linear Regression Model

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()

lr.fit(X_train, y_train)

y_pred_lr = lr.predict(X_test)

# %% [raw]
# Evaluate Linear Regression

# %%
from sklearn.metrics import (
    mean_absolute_error,
    mean_squared_error,
    r2_score
)
import numpy as np

print("Linear Regression Performance")
print("-"*40)

print("R² Score:", round(r2_score(y_test, y_pred_lr),3))

print("MAE:", round(mean_absolute_error(y_test, y_pred_lr),3))

print("RMSE:", round(np.sqrt(mean_squared_error(y_test, y_pred_lr)),3))
# Out:
# Linear Regression Performance
# ----------------------------------------
# R² Score: 0.569
# MAE: 17.297
# RMSE: 22.23

# %% [raw]
# Actual vs Predicted Values

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,6))

plt.scatter(y_test, y_pred_lr)

plt.xlabel("Actual Quality of Life")

plt.ylabel("Predicted Quality of Life")

plt.title("Linear Regression: Actual vs Predicted")

plt.plot(
    [y.min(), y.max()],
    [y.min(), y.max()],
    "r--"
)

plt.show()

# %% [raw]
# Train a Random Forest Model

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(
    n_estimators=200,
    random_state=42
)

rf.fit(X_train, y_train)

y_pred_rf = rf.predict(X_test)

# %% [raw]
# Evaluate Random Forest

# %%
print("Random Forest Performance")
print("-"*40)

print("R² Score:", round(r2_score(y_test, y_pred_rf),3))

print("MAE:", round(mean_absolute_error(y_test, y_pred_rf),3))

print("RMSE:", round(np.sqrt(mean_squared_error(y_test, y_pred_rf)),3))
# Out:
# Random Forest Performance
# ----------------------------------------
# R² Score: 0.816
# MAE: 9.798
# RMSE: 14.513

# %% [raw]
# Compare Both Models

# %%
comparison = pd.DataFrame({
    "Model": ["Linear Regression", "Random Forest"],
    "R² Score": [
        r2_score(y_test, y_pred_lr),
        r2_score(y_test, y_pred_rf)
    ],
    "MAE": [
        mean_absolute_error(y_test, y_pred_lr),
        mean_absolute_error(y_test, y_pred_rf)
    ],
    "RMSE": [
        np.sqrt(mean_squared_error(y_test, y_pred_lr)),
        np.sqrt(mean_squared_error(y_test, y_pred_rf))
    ]
})

comparison
# Out:
#                Model  R² Score        MAE       RMSE
# 0  Linear Regression  0.568605  17.297299  22.230376
# 1      Random Forest  0.816130   9.797988  14.513261

# %% [raw]
# The model with the higher R² and lower MAE/RMSE is generally the better performer on this dataset.

# %% [raw]
# Feature Importance
#
# Business Question: Which indicators contribute most to predicting Quality of Life?

# %%
importance = pd.DataFrame({
    "Feature": X.columns,
    "Importance": rf.feature_importances_
})

importance = importance.sort_values(
    by="Importance",
    ascending=False
)

importance
# Out:
#                           Feature  Importance
# 0          Purchasing Power Value    0.424161
# 3                   Climate Value    0.279888
# 7                 Pollution Value    0.118603
# 5  Property Price to Income Value    0.054845
# 6      Traffic Commute Time Value    0.040828
# 2               Health Care Value    0.032040
# 4            Cost of Living Value    0.029949
# 1                    Safety Value    0.019685

# %%
import os
import matplotlib.pyplot as plt

# Create images folder if it doesn't exist
os.makedirs("images", exist_ok=True)

# Sort the data (optional but recommended)
importance = importance.sort_values("Importance", ascending=True)

plt.figure(figsize=(8,6))

plt.barh(
    importance["Feature"],
    importance["Importance"]
)

plt.title("Random Forest Feature Importance")
plt.xlabel("Importance")

# Largest importance at the top
plt.gca().invert_yaxis()

plt.tight_layout()

# Save the figure BEFORE showing it
plt.savefig(
    "images/feature_importance.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %% [raw]
# K-Means Clustering
#
# This is Unsupervised Machine Learning, used to group similar countries.
#
# Standardize the Features

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_scaled = scaler.fit_transform(X)

# %% [raw]
# Elbow Method

# %%
from sklearn.cluster import KMeans

wcss = []

for i in range(1,11):

    kmeans = KMeans(
        n_clusters=i,
        random_state=42,
        n_init=10
    )

    kmeans.fit(X_scaled)

    wcss.append(kmeans.inertia_)

plt.figure(figsize=(8,5))

plt.plot(range(1,11), wcss, marker="o")

plt.xlabel("Number of Clusters")

plt.ylabel("WCSS")

plt.title("Elbow Method")

plt.show()

# %% [raw]
# Choose the value of k where the curve starts to level off (the "elbow").

# %% [raw]
# Build the Final K-Means Model
#
# If the elbow suggests 4 clusters, for example:

# %%
kmeans = KMeans(
    n_clusters=4,
    random_state=42,
    n_init=10
)

df["Cluster"] = kmeans.fit_predict(X_scaled)

df.head()
# Out:
#          country  Purchasing Power Value Purchasing Power Category  \
# 0    Afghanistan                   32.15                  Very Low
# 1  Aland Islands                  125.01                 Very High
# 2        Albania                   42.82                       Low
# 3       Alderney                   52.70                   Unknown
# 4        Algeria                   27.60                  Very Low
#
#    Safety Value Safety Category  Health Care Value Health Care Category  \
# 0         25.33             Low              24.24                  Low
# 1         71.81            High              79.72                 High
# 2         55.52        Moderate              48.21             Moderate
# 3         83.79       Very High             100.00            Very High
# 4         47.54        Moderate              54.43             Moderate
#
#    Climate Value Climate Category  Cost of Living Value  \
# 0          80.60          Unknown                 21.08
# ...

# %% [raw]
#  Cluster Summary

# %%
cluster_summary = df.groupby("Cluster")[
    [
        "Quality of Life Value",
        "Purchasing Power Value",
        "Safety Value",
        "Health Care Value",
        "Pollution Value"
    ]
].mean()

cluster_summary
# Out:
#          Quality of Life Value  Purchasing Power Value  Safety Value  \
# Cluster
# 0                   155.042561              107.007439     69.243171
# 1                   114.289375               42.983542     43.908750
# 2                   123.204078               45.039417     50.875146
# 3                   130.420000               20.873333     42.853333
#
#          Health Care Value  Pollution Value
# Cluster
# 0                70.155244        38.466585
# 1                56.474583        71.603750
# 2                50.370583        65.074951
# 3                45.740000        60.480000

# %% [raw]
# Visualize Clusters

# %%
import os
import matplotlib.pyplot as plt

# Create images folder if it doesn't exist
os.makedirs("images", exist_ok=True)

plt.figure(figsize=(10,6))

scatter = plt.scatter(
    df["Purchasing Power Value"],
    df["Quality of Life Value"],
    c=df["Cluster"],
    s=70,
    alpha=0.8
)

plt.xlabel("Purchasing Power Value")
plt.ylabel("Quality of Life Value")
plt.title("K-Means Clustering of Countries")

# Add colorbar
plt.colorbar(scatter, label="Cluster")

plt.tight_layout()

# Save BEFORE showing
plt.savefig(
    "images/kmeans_clusters.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %% [raw]
# Import GridSearchCV

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

# %% [raw]
# Create the Parameter Grid
#
# These are the values that GridSearchCV will test.

# %%
param_grid = {
    "n_estimators": [100, 200, 300],
    "max_depth": [None, 10, 20, 30],
    "min_samples_split": [2, 5, 10],
    "min_samples_leaf": [1, 2, 4],
    "max_features": ["sqrt", "log2"]
}

# %% [raw]
# Create the Random Forest Model

# %%
rf = RandomForestRegressor(random_state=42)

# %% [raw]
# Run Grid Search

# %%
grid_search = GridSearchCV(
    estimator=rf,
    param_grid=param_grid,
    cv=5,
    scoring="r2",
    n_jobs=-1
)

grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(random_state=42), n_jobs=-1,
#              param_grid={'max_depth': [None, 10, 20, 30],
#                          'max_features': ['sqrt', 'log2'],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [100, 200, 300]},
#              scoring='r2')

# %% [raw]
# View the Best Parameters

# %%
print("Best Parameters:")
print(grid_search.best_params_)
# Out:
# Best Parameters:
# {'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}

# %% [raw]
# Best Cross-Validation Score

# %%
print("Best Cross-Validation R²:")
print(grid_search.best_score_)
# Out:
# Best Cross-Validation R²:
# 0.6423344769565544

# %% [raw]
# Build the Optimized Model

# %%
best_rf = grid_search.best_estimator_

best_rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_depth=10, max_features='log2', random_state=42)

# %% [raw]
# Make Predictions

# %%
pred_best = best_rf.predict(X_test)

# %% [raw]
# Evaluate the Optimized Model

# %%
from sklearn.metrics import (
    r2_score,
    mean_absolute_error,
    mean_squared_error
)
import numpy as np

print("Optimized Random Forest")
print("-" * 40)

print("R²:", round(r2_score(y_test, pred_best), 3))
print("MAE:", round(mean_absolute_error(y_test, pred_best), 3))
print("RMSE:", round(np.sqrt(mean_squared_error(y_test, pred_best)), 3))
# Out:
# Optimized Random Forest
# ----------------------------------------
# R²: 0.733
# MAE: 11.858
# RMSE: 17.505

# %% [raw]
# Actual vs Predicted

# %%
plt.figure(figsize=(8,6))

plt.scatter(
    y_test,
    y_pred_rf
)

plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title("Actual vs Predicted")

plt.tight_layout()

plt.savefig(
    "images/actual_vs_predicted.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %% [raw]
# Compare Models

# %%
comparison = pd.DataFrame({
    "Model": [
        "Linear Regression",
        "Random Forest",
        "Optimized Random Forest"
    ],
    "R²": [
        r2_score(y_test, y_pred_lr),
        r2_score(y_test, y_pred_rf),
        r2_score(y_test, pred_best)
    ],
    "MAE": [
        mean_absolute_error(y_test, y_pred_lr),
        mean_absolute_error(y_test, y_pred_rf),
        mean_absolute_error(y_test, pred_best)
    ],
    "RMSE": [
        np.sqrt(mean_squared_error(y_test, y_pred_lr)),
        np.sqrt(mean_squared_error(y_test, y_pred_rf)),
        np.sqrt(mean_squared_error(y_test, pred_best))
    ]
})

comparison
# Out:
#                      Model        R²        MAE       RMSE
# 0        Linear Regression  0.568605  17.297299  22.230376
# 1            Random Forest  0.816130   9.797988  14.513261
# 2  Optimized Random Forest  0.732515  11.857763  17.504876

# %% [raw]
# Import the Required Libraries

# %%
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestRegressor
import numpy as np

# %% [raw]
# Create the Model

# %%
rf = RandomForestRegressor(
    n_estimators=200,
    random_state=42
)

# %% [raw]
# Perform 5-Fold Cross-Validation

# %%
cv_scores = cross_val_score(
    rf,
    X,
    y,
    cv=5,
    scoring="r2"
)

# %% [raw]
# Notice that we're using the full dataset (X and y), not X_train and X_test. Cross-validation creates its own training and testing splits internall

# %% [raw]
# Display the Results

# %%
print("Cross-Validation R² Scores:")
print(cv_scores)
# Out:
# Cross-Validation R² Scores:
# [0.23653859 0.74817282 0.70738544 0.74274992 0.70804096]

# %% [raw]
# Calculate the Average Score

# %%
print("Average R²:", np.mean(cv_scores))
# Out:
# Average R²: 0.6285775441847212

# %% [raw]
# Calculate the Standard Deviation

# %%
print("Standard Deviation:", np.std(cv_scores))
# Out:
# Standard Deviation: 0.19675264658726158

# %% [raw]
# Display Everything Clearly

# %%
print("="*50)
print("Random Forest Cross-Validation")
print("="*50)

print("Fold Scores:")
print(cv_scores)

print()

print("Average R²:", round(np.mean(cv_scores),3))

print("Standard Deviation:", round(np.std(cv_scores),3))
# Out:
# ...
# Random Forest Cross-Validation
# ...
# Fold Scores:
# [0.23653859 0.74817282 0.70738544 0.74274992 0.70804096]
#
# Average R²: 0.629
# Standard Deviation: 0.197

# %% [raw]
# Install XGBoost

# %%
# !pip install xgboost

# %% [raw]
# Import Libraries

# %%
from xgboost import XGBRegressor

from sklearn.metrics import (
    r2_score,
    mean_absolute_error,
    mean_squared_error
)

import numpy as np

# %% [raw]
# Build the XGBoost Model

# %%
xgb = XGBRegressor(
    n_estimators=200,
    learning_rate=0.05,
    max_depth=4,
    random_state=42
)

# %% [raw]
# Train the Model

# %%
xgb.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=True, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.05, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=4,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=200,
#              n_jobs=None, num_parallel_tree=None, ...)

# %% [raw]
# Make Predictions

# %%
y_pred_xgb = xgb.predict(X_test)

# %% [raw]
# Evaluate the Model

# %%
print("="*50)
print("XGBoost Performance")
print("="*50)

print("R²:", round(r2_score(y_test, y_pred_xgb),3))

print("MAE:", round(mean_absolute_error(y_test, y_pred_xgb),3))

print("RMSE:", round(np.sqrt(mean_squared_error(y_test, y_pred_xgb)),3))
# Out:
# ...
# XGBoost Performance
# ...
# R²: 0.791
# MAE: 8.887
# RMSE: 15.461

# %% [raw]
# Feature Importance

# %%
importance = pd.DataFrame({
    "Feature": X.columns,
    "Importance": xgb.feature_importances_
})

importance = importance.sort_values(
    by="Importance",
    ascending=False
)

importance
# Out:
#                           Feature  Importance
# 0          Purchasing Power Value    0.348216
# 3                   Climate Value    0.291427
# 7                 Pollution Value    0.156283
# 5  Property Price to Income Value    0.084051
# 6      Traffic Commute Time Value    0.050926
# 2               Health Care Value    0.033488
# 1                    Safety Value    0.023616
# 4            Cost of Living Value    0.011992

# %% [raw]
# Visualize Feature Importance

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))

plt.barh(
    importance["Feature"],
    importance["Importance"]
)

plt.xlabel("Importance")

plt.title("XGBoost Feature Importance")

plt.gca().invert_yaxis()

plt.show()

# %% [raw]
# Cross-Validation

# %%
from sklearn.model_selection import cross_val_score

cv_scores = cross_val_score(
    xgb,
    X,
    y,
    cv=5,
    scoring="r2"
)

print("="*50)
print("XGBoost Cross Validation")
print("="*50)

print("Fold Scores:")

print(cv_scores)

print()

print("Average R²:", round(np.mean(cv_scores),3))

print("Standard Deviation:", round(np.std(cv_scores),3))
# Out:
# ...
# XGBoost Cross Validation
# ...
# Fold Scores:
# [0.16095653 0.8195284  0.81712638 0.75663234 0.74435331]
#
# Average R²: 0.66
# Standard Deviation: 0.251

# %% [raw]
# Compare All Models

# %%
comparison = pd.DataFrame({

    "Model":[
        "Linear Regression",
        "Random Forest",
        "XGBoost"
    ],

    "R²":[
        r2_score(y_test,y_pred_lr),
        r2_score(y_test,y_pred_rf),
        r2_score(y_test,y_pred_xgb)
    ],

    "MAE":[
        mean_absolute_error(y_test,y_pred_lr),
        mean_absolute_error(y_test,y_pred_rf),
        mean_absolute_error(y_test,y_pred_xgb)
    ],

    "RMSE":[
        np.sqrt(mean_squared_error(y_test,y_pred_lr)),
        np.sqrt(mean_squared_error(y_test,y_pred_rf)),
        np.sqrt(mean_squared_error(y_test,y_pred_xgb))
    ]

})

comparison
# Out:
#                Model        R²        MAE       RMSE
# 0  Linear Regression  0.568605  17.297299  22.230376
# 1      Random Forest  0.816130   9.797988  14.513261
# 2            XGBoost  0.791324   8.887130  15.461274

# %%
import os
import matplotlib.pyplot as plt

os.makedirs("images", exist_ok=True)

comparison_sorted = comparison.sort_values("R²")

plt.figure(figsize=(8,6))

bars = plt.barh(
    comparison_sorted["Model"],
    comparison_sorted["R²"]
)

plt.xlabel("R² Score")
plt.title("Machine Learning Model Comparison")

# Add value labels
for bar in bars:
    width = bar.get_width()
    plt.text(
        width + 0.01,
        bar.get_y() + bar.get_height()/2,
        f"{width:.3f}",
        va="center"
    )

plt.tight_layout()

plt.savefig(
    "images/model_comparison.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %% [raw]
# Install SHAP

# %%
# !pip install shap

# %% [raw]
# Import Libraries

# %%
import shap
import matplotlib.pyplot as plt

# %% [raw]
# Create the SHAP Explainer

# %%
explainer = shap.TreeExplainer(best_rf)

# %% [raw]
# Calculate SHAP Values

# %%
shap_values = explainer.shap_values(X)

# %% [raw]
# SHAP Summary Plot ⭐
#
# This is the most important SHAP visualization.

# %%
import os
import shap
import matplotlib.pyplot as plt

os.makedirs("images", exist_ok=True)

shap.summary_plot(
    shap_values,
    X,
    show=False
)

plt.tight_layout()

plt.savefig(
    "images/shap_summary.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %% [raw]
# What it shows
# Features are ranked by importance.
# Each dot represents one country.
# Red indicates higher feature values.
# Blue indicates lower feature values.
# Features at the top have the greatest influence on predictions.

# %% [raw]
# SHAP Bar Plot

# %%
shap.summary_plot(
    shap_values,
    X,
    plot_type="bar"
)

# %% [raw]
# Explain One Country (Waterfall Plot) Let's explain the first country in the dataset.

# %%
sample = 0

explanation = shap.Explanation(
    values=shap_values[sample],
    base_values=explainer.expected_value,
    data=X.iloc[sample],
    feature_names=X.columns
)

shap.plots.waterfall(explanation)

# %% [raw]
# The waterfall plot shows:
#
# Which features pushed the prediction higher.
# Which features pushed it lower.
# How those contributions combine to produce the final predicted Quality of Life score.

# %% [raw]
# (Optional): Force Plot

# %%
shap.initjs()

shap.force_plot(
    explainer.expected_value,
    shap_values[0],
    X.iloc[0]
)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# ...

# %% [raw]
# This interactive visualization works best in Jupyter Notebook.

# %% [raw]
# Business Question
#
# Can countries be grouped into similar Quality of Life profiles when the socioeconomic indicators are reduced to two principal components?

# %% [raw]
# Import Libraries

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import pandas as pd

# %% [raw]
# Standardize the Data
# PCA is sensitive to scale, so standardization is essential.

# %%
scaler = StandardScaler()

X_scaled = scaler.fit_transform(X)

# %% [raw]
# Apply PCA
#
# We'll reduce the data from 8 features to 2 principal components.

# %%
pca = PCA(n_components=2)

principal_components = pca.fit_transform(X_scaled)

# %% [raw]
# Create a DataFrame

# %%
pca_df = pd.DataFrame(
    principal_components,
    columns=["PC1", "PC2"]
)

pca_df.head()
# Out:
#         PC1       PC2
# 0 -3.571416 -0.781702
# 1  2.907801  0.336642
# 2 -1.088838  0.034045
# 3  3.497235  0.706559
# 4 -1.534240  0.172988

# %% [raw]
# Variance Explained
#
# This tells us how much information the two principal components retain.

# %%
print("Explained Variance Ratio:")

print(pca.explained_variance_ratio_)
# Out:
# Explained Variance Ratio:
# [0.32681474 0.14644107]

# %% [raw]
# Meaning:
#
# PC1 explains 52%
# PC2 explains 23%
#
# Together:
#
# 75% of the original information.

# %% [raw]
# Total Variance

# %%
print("Total Variance Explained:")

print(sum(pca.explained_variance_ratio_))
# Out:
# Total Variance Explained:
# 0.47325581093600355

# %% [raw]
# nterpretation:
#
# The first two principal components explain approximately 75% of the variation in the original dataset.

# %% [raw]
# Scatter Plot
#
# Since you've already created K-Means clusters, use them here.

# %%
import os
import matplotlib.pyplot as plt

os.makedirs("images", exist_ok=True)

plt.figure(figsize=(10,7))

scatter = plt.scatter(
    pca_df["PC1"],
    pca_df["PC2"],
    c=df["Cluster"],
    s=80,
    alpha=0.8
)

plt.colorbar(scatter, label="Cluster")

plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")
plt.title("PCA Visualization of Country Clusters")

plt.tight_layout()

plt.savefig(
    "images/pca_visualization.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %%
import os
import matplotlib.pyplot as plt

os.makedirs("images", exist_ok=True)

plt.figure(figsize=(10,7))

scatter = plt.scatter(
    pca_df["PC1"],
    pca_df["PC2"],
    c=df["Cluster"],
    s=80,
    alpha=0.8
)

plt.colorbar(scatter, label="Cluster")

plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")
plt.title("PCA Visualization of Country Clusters")

plt.tight_layout()

plt.savefig(
    "images/pca_visualization.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %% [raw]
# Add Country Names (Optional)
#
# If you want a more informative plot:

# %%
plt.figure(figsize=(14,10))

plt.scatter(
    pca_df["PC1"],
    pca_df["PC2"],
    c=df["Cluster"]
)

for i, country in enumerate(df["country"]):
    plt.text(
        pca_df.iloc[i,0],
        pca_df.iloc[i,1],
        country,
        fontsize=7
    )

plt.xlabel("Principal Component 1")

plt.ylabel("Principal Component 2")

plt.title("Countries in PCA Space")

plt.show()

# %% [raw]
# This can become crowded with 236 countries, so use it mainly for exploration.

# %% [raw]
# PCA Loadings

# %%
loadings = pd.DataFrame(
    pca.components_.T,
    columns=["PC1","PC2"],
    index=X.columns
)

loadings
# Out:
#                                      PC1       PC2
# Purchasing Power Value          0.443193 -0.154305
# Safety Value                    0.468147 -0.129114
# Health Care Value               0.424879 -0.170408
# Climate Value                  -0.071477  0.591513
# Cost of Living Value            0.318659  0.350497
# Property Price to Income Value -0.170687  0.496926
# Traffic Commute Time Value     -0.254649 -0.370404
# Pollution Value                -0.450846 -0.271313

# %% [raw]
# Business Interpretation
#
# If Purchasing Power has a large positive loading on PC1, you can say:
#
# Countries with higher purchasing power tend to score higher on the first principal component,
# making Purchasing Power one of the dominant factors shaping the overall country profile.

# %% [raw]
# train

# %%
rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor(n_estimators=200, random_state=42)

# %% [raw]
# Import Joblib

# %%
import joblib as jb

# %% [raw]
# Save the Best Model

# %%
jb.dump(rf, "quality_of_life_model.pkl")
# Out:
# ['quality_of_life_model.pkl']

# %% [raw]
# Make Predictions Using the Loaded Model

# %%
predictions = loaded_model.predict(X_test)

print(predictions[:10])

# %% [raw]
# Verify the Loaded Model

# %%
from sklearn.metrics import r2_score

predictions = loaded_model.predict(X_test)

print("R² Score:", round(r2_score(y_test, predictions), 3))

# %% [raw]
# If the score matches your original Random Forest result, your model has been saved and loaded successfully.

# %% [raw]
# Save the Scaler (Highly Recommended)
#
# Your model expects input data to be processed the same
# way as during training.
#     If you used a StandardScaler for your final model or
# plan to use one in your application, save it too.

# %%
joblib.dump(scaler, "scaler.pkl")

# %%
loaded_scaler = joblib.load("scaler.pkl")

# %% [raw]
# Note: Only save the scaler if it is actually part of the
# preprocessing used by your deployed prediction pipeline.
#     Your Random Forest model itself does not require scaling,
# but your PCA and K-Means analyses did. If your future
# Streamlit app uses only the Random Forest model with raw input
# features, you may not need the scaler.

# %%
import os

os.makedirs("images", exist_ok=True)
